# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import os

# %% [markdown]
# # Abstracts

# %%
abstract = pd.read_csv("../Data/Abstract/RePORTER_PRJABS.csv")

# %% [markdown]
# # Projects

# %%
fs = os.listdir("../Data/Project/")

# %%
proj = [pd.read_csv("../Data/Project/" + f, low_memory=False) for f in fs if ((".csv" in f) and ("RePORTER_PRJ_C" in f)) ]

# %%
project = pd.concat(proj, ignore_index=True)

# %%
project.to_csv("../Data/Project/RePORTER_PRJ.csv")

# %% [markdown]
# # Epistasis

# %%
project
# Out:
#         ACTIVITY ADMINISTERING_IC  APPLICATION_ID  APPLICATION_TYPE  \
# 0            P50               AG         9248847               5.0
# 1            P50               AG         9248853               5.0
# 2            P01               HL         9249662               5.0
# 3            P01               HL         9249666               5.0
# 4            R01               NS         9250220               5.0
# 5            K24               NS         9250819               5.0
# 6            R01               HL         9251298               5.0
# 7            U19               AI         9252367               5.0
# 8            R01               HL         9254593               5.0
# 9            P01               HL         9258331               5.0
# 10           P01               HL         9258333               5.0
# 11           F31               HL         9258978               1.0
# 12           R21               HD         9259800               5.0
# ...

# %%
abstract
# Out:
#          Unnamed: 0  APPLICATION_ID  \
# 0                 0         9372331
# 1                 1         9245975
# 2                 2         9124294
# 3                 3         9245195
# 4                 4         9372282
# 5                 5         9395371
# 6                 6         9406519
# 7                 7         9387555
# 8                 8         9307266
# 9                 9         9186981
# 10               10         9236548
# 11               11         9186986
# 12               12         9391143
# 13               13         9250361
# 14               14         9401920
# 15               15         9404529
# 16               16         9189635
# 17               17         9324393
# 18               18         9258570
# 19               19         9205530
# 20               20         9186983
# 21               21         9384915
# 22               22         9404662
# 23               23         9245973
# 24               24         9404520
# ...

# %%
abs_test = abstract.get("ABSTRACT_TEXT")

# %%
epistasis = abstract[abstract['ABSTRACT_TEXT'].str.contains("epistasis", regex = False, case = False, na=False)] 
epistasis
# Out:
#          Unnamed: 0  APPLICATION_ID  \
# 550             550         9327347
# 682             682         9312511
# 1238           1238         8215813
# 1755           1755         8248274
# 2090           2090         8294532
# 2535           2535         8290407
# 5329           5329         8318601
# 7386           7386         8233997
# 10446         10446         8234266
# 10825         10825         8208087
# 11004         11004         8231334
# 13012         13012         8212332
# 13562         13562         8235919
# 13908         13908         8249401
# 14587         14587         8322524
# 16653         16653         8310586
# 17115         17115         8217507
# 18628         18628         8256985
# 19280         19280         8281579
# 19833         19833         8321897
# 20344         20344         8197043
# 21164         21164         8217320
# 21577         21577         8341638
# 22104         22104         8249383
# 22505         22505         8370018
# ...

# %%
projects_epistasis = project[project['APPLICATION_ID'].isin(epistasis['APPLICATION_ID'])]

# %%
projects_epistasis
# Out:
#         ACTIVITY ADMINISTERING_IC  APPLICATION_ID  APPLICATION_TYPE  \
# 101          U01               HL         9312511               1.0
# 457          F31               NS         9327347               1.0
# 2526         F32               CA         6498022               5.0
# 3010         F32               GM         6518871               5.0
# 3225         F32               GM         6487120               1.0
# 3348         F32               HD         6520715               5.0
# 3349         F32               HD         6585440               5.0
# 7146         K22               DE         6695926               7.0
# 7147         K22               DE         6524170               5.0
# 18967        P01               DK         6583559               2.0
# 19103        P01               DK         6657068               5.0
# 20353        P01               HD         6536235               5.0
# 23555        P20               RR         6697015               1.0
# ...

# %%
activity_by_fy = pd.crosstab(projects_epistasis.FY, projects_epistasis.ACTIVITY)
activity_by_fy.to_csv("Activity.by.FY.csv")
activity_by_fy
# Out:
# ACTIVITY  DP2  F30  F31  F32  I01  K01  K22  K24  K25  K99 ...   R43  R56  \
# FY                                                         ...
# 2000        0    0    0    3    0    0    0    1    0    0 ...     0    0
# 2001        0    0    0    3    0    0    1    0    0    0 ...     0    0
# 2002        0    0    0    5    0    0    2    0    0    0 ...     0    0
# 2003        0    0    0    4    0    0    1    0    0    0 ...     0    0
# 2004        0    0    1    5    0    0    1    0    1    0 ...     0    0
# 2005        0    0    1    5    0    0    0    0    1    0 ...     0    0
# 2006        0    0    2    7    0    0    0    0    1    0 ...     0    0
# 2007        0    0    2    7    0    0    0    0    1    1 ...     0    0
# 2008        0    0    2    6    0    0    0    0    1    2 ...     0    1
# 2009        0    0    1    7    0    0    0    0    0    1 ...     0    1
# 2010        1    0    2    4    0    0    0    0    0    2 ...     1    0
# ...

# %%
projects_epistasis.plot(x='FY', y='DIRECT_COST_AMT', style='o', xlim=(2010, 2018))

# %%
projects_epistasis_r01 = projects_epistasis[projects_epistasis['ACTIVITY'] == "R01"]

# %%
projects_epistasis_r01.plot(x='FY', y='DIRECT_COST_AMT', style='o', xlim=(2010, 2018))
